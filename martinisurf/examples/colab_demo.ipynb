# %% [markdown]
# # 🧬 MartiniSurf – Google Colab Demo
# ### *Automated enzyme–surface system builder for Martini3 & GōMartini*
#
# This notebook demonstrates how to install and run **MartiniSurf** entirely in Google Colab.
# It includes:
# - Installation from GitHub
# - Generating Martini surfaces
# - Orienting enzymes using anchor residues
# - Building full Martini + GōMartini simulation systems
# - Optional visualization with PyVista

# %% [markdown]
# ## 🔧 1. Install MartiniSurf from GitHub
# ### If your repository is **public**, run this:

# %% [markdown]
# ### If your repository is **private**, use a GitHub token:

# %%
## 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

# %%
import getpass
token = getpass.getpass("Introduce tu token de GitHub: ")

# !git clone https://{token}@github.com/jjimenezgar/MartiniSurf.git
# %cd MartiniSurf
# !pip install -e .
# Out:
# Cloning into 'MartiniSurf'...
# remote: Enumerating objects: 495, done.
# remote: Counting objects: 100% (372/372), done.
# remote: Compressing objects: 100% (251/251), done.
# remote: Total 495 (delta 223), reused 236 (delta 100), pack-reused 123 (from 1)
# Receiving objects: 100% (495/495), 5.04 MiB | 15.35 MiB/s, done.
# Resolving deltas: 100% (262/262), done.
# /home/jjimenez/Documents/Research_P450/SurfMartini2/martinisurf/examples/MartiniSurf
# /bin/pip:6: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import load_entry_point
# Obtaining file:///home/jjimenez/Documents/Research_P450/SurfMartini2/martinisurf/examples/MartiniSurf
# Requirement already satisfied: numpy in /home/jjimenez/.local/lib/python3.8/site-packages (from martinisurf==1.0.0) (1.23.5)
# Collecting pyvista
#   Downloading pyvista-0.44.2-py3-none-any.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 4.1 MB/s eta 0:00:01
# Requirement already satisfied: MDAnalysis in /home/jjimenez/.local/lib/python3.8/site-packages (from martinisurf==1.0.0) (2.4.3)
# Requirement already satisfied: scipy in /home/jjimenez/.local/lib/python3.8/site-packages (from martinisurf==1.0.0) (1.10.1)
# Collecting vermouth
#   Downloading vermouth-0.15.0-py2.py3-none-any.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 34.4 MB/s eta 0:00:01
# Requirement already satisfied: matplotlib>=3.0.1 in /home/jjimenez/.local/lib/python3.8/site-packages (from pyvista->martinisurf==1.0.0) (3.7.5)
# Requirement already satisfied: pillow in /usr/lib/python3/dist-packages (from pyvista->martinisurf==1.0.0) (7.0.0)
# Collecting pooch
#   Downloading pooch-1.8.2-py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 576 kB/s  eta 0:00:01
# Collecting scooby>=0.5.1
#   Downloading scooby-0.11.0-py3-none-any.whl (19 kB)
# Collecting vtk<9.4.0
#   Downloading vtk-9.3.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (92.1 MB)
#      |████████████████████████████████| 92.1 MB 42 kB/s s eta 0:00:01
# Requirement already satisfied: typing-extensions in /home/jjimenez/.local/lib/python3.8/site-packages (from pyvista->martinisurf==1.0.0) (4.11.0)
# Collecting biopython>=1.80
#   Using cached biopython-1.83-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
# Requirement already satisfied: networkx>=2.0 in /home/jjimenez/.local/lib/python3.8/site-packages (from MDAnalysis->martinisurf==1.0.0) (3.1)
# Requirement already satisfied: GridDataFormats>=0.4.0 in /home/jjimenez/.local/lib/python3.8/site-packages (from MDAnalysis->martinisurf==1.0.0) (1.0.1)
# Requirement already satisfied: mmtf-python>=1.0.0 in /home/jjimenez/.local/lib/python3.8/site-packages (from MDAnalysis->martinisurf==1.0.0) (1.1.3)
# Requirement already satisfied: joblib>=0.12 in /home/jjimenez/.local/lib/python3.8/site-packages (from MDAnalysis->martinisurf==1.0.0) (1.4.0)
# Requirement already satisfied: tqdm>=4.43.0 in /home/jjimenez/.local/lib/python3.8/site-packages (from MDAnalysis->martinisurf==1.0.0) (4.66.2)
# Requirement already satisfied: threadpoolctl in /home/jjimenez/.local/lib/python3.8/site-packages (from MDAnalysis->martinisurf==1.0.0) (3.4.0)
# Requirement already satisfied: packaging in /home/jjimenez/.local/lib/python3.8/site-packages (from MDAnalysis->martinisurf==1.0.0) (24.0)
# Requirement already satisfied: fasteners in /home/jjimenez/.local/lib/python3.8/site-packages (from MDAnalysis->martinisurf==1.0.0) (0.19)
# Requirement already satisfied: gsd>=1.9.3 in /home/jjimenez/.local/lib/python3.8/site-packages (from MDAnalysis->martinisurf==1.0.0) (3.2.1)
# Collecting pbr
#   Downloading pbr-7.0.3-py2.py3-none-any.whl (131 kB)
#      |████████████████████████████████| 131 kB 62.6 MB/s eta 0:00:01
# Requirement already satisfied: contourpy>=1.0.1 in /home/jjimenez/.local/lib/python3.8/site-packages (from matplotlib>=3.0.1->pyvista->martinisurf==1.0.0) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/lib/python3/dist-packages (from matplotlib>=3.0.1->pyvista->martinisurf==1.0.0) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/jjimenez/.local/lib/python3.8/site-packages (from matplotlib>=3.0.1->pyvista->martinisurf==1.0.0) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/lib/python3/dist-packages (from matplotlib>=3.0.1->pyvista->martinisurf==1.0.0) (1.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib>=3.0.1->pyvista->martinisurf==1.0.0) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.7 in /home/jjimenez/.local/lib/python3.8/site-packages (from matplotlib>=3.0.1->pyvista->martinisurf==1.0.0) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0; python_version < "3.10" in /home/jjimenez/.local/lib/python3.8/site-packages (from matplotlib>=3.0.1->pyvista->martinisurf==1.0.0) (6.4.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /home/jjimenez/.local/lib/python3.8/site-packages (from pooch->pyvista->martinisurf==1.0.0) (4.2.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/lib/python3/dist-packages (from pooch->pyvista->martinisurf==1.0.0) (2.22.0)
# Requirement already satisfied: mrcfile in /home/jjimenez/.local/lib/python3.8/site-packages (from GridDataFormats>=0.4.0->MDAnalysis->martinisurf==1.0.0) (1.5.0)
# Requirement already satisfied: msgpack>=1.0.0 in /home/jjimenez/.local/lib/python3.8/site-packages (from mmtf-python>=1.0.0->MDAnalysis->martinisurf==1.0.0) (1.0.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from pbr->vermouth->martinisurf==1.0.0) (69.5.1)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib>=3.0.1->pyvista->martinisurf==1.0.0) (1.14.0)
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in /home/jjimenez/.local/lib/python3.8/site-packages (from importlib-resources>=3.2.0; python_version < "3.10"->matplotlib>=3.0.1->pyvista->martinisurf==1.0.0) (3.18.1)
# ERROR: prody 2.4.1 has requirement biopython<=1.79, but you'll have biopython 1.83 which is incompatible.
# Installing collected packages: pooch, scooby, vtk, pyvista, pbr, vermouth, martinisurf, biopython
#   Running setup.py develop for martinisurf
#   Attempting uninstall: biopython
#     Found existing installation: biopython 1.79
#     Uninstalling biopython-1.79:
#       Successfully uninstalled biopython-1.79
# Successfully installed biopython-1.83 martinisurf pbr-7.0.3 pooch-1.8.2 pyvista-0.44.2 scooby-0.11.0 vermouth-0.15.0 vtk-9.3.1

# %% [markdown]
# ## ✔️ 2. Verify Installation

# %%
# !martinisurf -h
# Out:
# Traceback (most recent call last):
#   File "/home/jjimenez/.local/bin/martinisurf", line 33, in <module>
#     sys.exit(load_entry_point('martinisurf', 'console_scripts', 'martinisurf')())
#   File "/home/jjimenez/Documents/Research_P450/SurfMartini2/martinisurf/examples/MartiniSurf/martinisurf/__main__.py", line 94, in main
#     from martinisurf.pipeline import build_parser
#   File "/home/jjimenez/Documents/Research_P450/SurfMartini2/martinisurf/examples/MartiniSurf/martinisurf/pipeline.py", line 18, in <module>
#     from martinisurf.utils.pdb_generation import load_clean_pdb
#   File "/home/jjimenez/Documents/Research_P450/SurfMartini2/martinisurf/examples/MartiniSurf/martinisurf/utils/pdb_generation.py", line 52, in <module>
#     def simple_clean_pdb(infile: Path, outfile: Path, chain: str | None = None) -> Path:
# TypeError: unsupported operand type(s) for |: 'type' and 'NoneType'

# %% [markdown]
# ## 🏗️ 3. Build a Full Martini + GōMartini System

# %%
# !martinisurf --pdb 1RJW --moltype Protein --lx 20 --ly 20 --surface-bead C1 --anchor 1 8 10 11 --anchor 2 1025 1027 1028 --dist 10 --merge A,B,C,D

# %% [markdown]
# ## 👀 4. Optional: Visualize in Colab (PyVista)

# %%
import pyvista as pv
mesh = pv.read('surface.gro')
plotter = pv.Plotter(notebook=True)
plotter.add_points(mesh.points)
plotter.show()

# %% [markdown]
# ---
# # 🎉 Done!
#
# Your MartiniSurf environment is now fully operational in Google Colab.
# You can automate enzyme–surface simulations, generate Martini/GōMartini setups, and visualize your systems interactively.
